# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("complete_house_data.csv")

# %%
data
# Out:
#        year     state state_po  state_fips  state_cen  state_ic    office  \
# 0      1976   Alabama       AL           1         63        41  US House
# 1      1976   Alabama       AL           1         63        41  US House
# 2      1976   Alabama       AL           1         63        41  US House
# 3      1976   Alabama       AL           1         63        41  US House
# 4      1976   Alabama       AL           1         63        41  US House
# ...     ...       ...      ...         ...        ...       ...       ...
# 29631  2018  Maryland       MD          24         52        52  US House
# 29632  2018  Maryland       MD          24         52        52  US House
# 29633  2018  Maryland       MD          24         52        52  US House
# 29634  2018  Maryland       MD          24         52        52  US House
# 29635  2018  Maryland       MD          24         52        52  US House
#
#        district stage runoff  special         candidate        party  writein  \
# 0             1   gen  False    False    Bill Davenport     democrat    False
# 1             1   gen  False    False      Jack Edwards   republican    False
# 2             1   gen  False    False               NaN          NaN     True
# 3             2   gen  False    False  J. Carole Keahey     democrat    False
# 4             2   gen  False    False               NaN          NaN     True
# ...         ...   ...    ...      ...               ...          ...      ...
# 29631         7   gen    NaN    False               NaN          NaN     True
# 29632         8   gen    NaN    False      Jamie Raskin     democrat    False
# 29633         8   gen    NaN    False      Jasen Wunder  libertarian    False
# 29634         8   gen    NaN    False        John Walsh   republican    False
# 29635         8   gen    NaN    False               NaN          NaN     True
#
#         mode  candidatevotes  totalvotes  unofficial   version
# 0      total           58906      157170       False  20200424
# 1      total           98257      157170       False  20200424
# 2      total               7      157170       False  20200424
# 3      total           66288      156362       False  20200424
# 4      total               5      156362       False  20200424
# ...      ...             ...         ...         ...       ...
# 29631  total             272      264710       False  20200424
# 29632  total          217679      319330       False  20200424
# 29633  total            4853      319330       False  20200424
# 29634  total           96525      319330       False  20200424
# 29635  total             273      319330       False  20200424
#
# [29636 rows x 19 columns]

# %%
district = data['district'].astype(str)

# %%
data['state_district'] = data['state_po'] + ", " + district

# %%
data_all = data.loc[data['year'] >= 2014]

# %%
data_2014 = data.loc[data['year'] == 2014]
data_2016 = data.loc[data['year'] == 2016]

# %%
data_2014
# Out:
#        year    state state_po  state_fips  state_cen  state_ic    office  \
# 25459  2014  Alabama       AL           1         63        41  US House
# 25460  2014  Alabama       AL           1         63        41  US House
# 25461  2014  Alabama       AL           1         63        41  US House
# 25462  2014  Alabama       AL           1         63        41  US House
# 25463  2014  Alabama       AL           1         63        41  US House
# ...     ...      ...      ...         ...        ...       ...       ...
# 26811  2014  Wyoming       WY          56         83        68  US House
# 26812  2014  Wyoming       WY          56         83        68  US House
# 26813  2014  Wyoming       WY          56         83        68  US House
# 26814  2014  Wyoming       WY          56         83        68  US House
# 26815  2014  Wyoming       WY          56         83        68  US House
#
#        district stage runoff  special              candidate         party  \
# 25459         1   gen    NaN    False          Bradley Byrne    republican
# 25460         1   gen    NaN    False                    NaN           NaN
# 25461         1   gen    NaN    False      Burton R. LeFlore      democrat
# 25462         2   gen    NaN    False            Martha Roby    republican
# 25463         2   gen    NaN    False           Erick Wright      democrat
# ...         ...   ...    ...      ...                    ...           ...
# 26811         0   gen    NaN    False             Blank Vote           NaN
# 26812         0   gen    NaN    False      Cynthia M. Lummis    republican
# 26813         0   gen    NaN    False        Richard Grayson      democrat
# 26814         0   gen    NaN    False  Daniel Clyde Cummings  constitution
# 26815         0   gen    NaN    False       Richard Brubaker   libertarian
#
#        writein   mode  candidatevotes  totalvotes  unofficial   version  \
# 25459    False  total          103758      152234       False  20200424
# 25460     True  total             198      152234       False  20200424
# 25461    False  total           48278      152234       False  20200424
# 25462    False  total          113103      167952       False  20200424
# 25463    False  total           54692      167952       False  20200424
# ...        ...    ...             ...         ...         ...       ...
# 26811    False  total            5683      171153       False  20200424
# 26812    False  total          113038      171153       False  20200424
# 26813    False  total           37803      171153       False  20200424
# 26814    False  total            6749      171153       False  20200424
# 26815    False  total            7112      171153       False  20200424
#
#       state_district
# 25459          AL, 1
# 25460          AL, 1
# 25461          AL, 1
# 25462          AL, 2
# 25463          AL, 2
# ...              ...
# 26811          WY, 0
# 26812          WY, 0
# 26813          WY, 0
# 26814          WY, 0
# 26815          WY, 0
#
# [1357 rows x 20 columns]

# %% [markdown]
# # 2018

# %%
data_2018 = data.loc[data['year'] == 2018]

# %%
## for rows with same state_district, take #1 in candidate votes then move onto the next state_district
#data.groupby('state_district')['candidatevotes'].apply(lambda x: list(x))
#data_2018.groupby(['state', 'district', 'state_district'])['candidatevotes']\
    #.apply(lambda x: max(list(x)) if len(list(x)) > 0 else np.nan)
    
max_votes = data_2018.groupby('state_district')['candidatevotes'].max()               
max_votes = pd.DataFrame(max_votes)

# %%
combined_df = max_votes.merge(data_2018[["year","state", "district", "candidatevotes", "state_district", "candidate", "party", "totalvotes", "state_fips","state_po"]],\
                          on = "state_district",  how = "left")
combined_df
# Out:
#      state_district  candidatevotes_x  year    state  district  \
# 0             AK, 0            149779  2018   Alaska         0
# 1             AK, 0            149779  2018   Alaska         0
# 2             AK, 0            149779  2018   Alaska         0
# 3             AL, 1            153228  2018  Alabama         1
# 4             AL, 1            153228  2018  Alabama         1
# ...             ...               ...   ...      ...       ...
# 1354          WY, 0            127963  2018  Wyoming         0
# 1355          WY, 0            127963  2018  Wyoming         0
# 1356          WY, 0            127963  2018  Wyoming         0
# 1357          WY, 0            127963  2018  Wyoming         0
# 1358          WY, 0            127963  2018  Wyoming         0
#
#       candidatevotes_y              candidate         party  totalvotes  \
# 0               131199        Alyse S. Galvin      democrat      282166
# 1               149779              Don Young    republican      282166
# 2                 1188                    NaN           NaN      282166
# 3                89226     Robert Kennedy Jr.      democrat      242617
# 4               153228          Bradley Byrne    republican      242617
# ...                ...                    ...           ...         ...
# 1354            127963             Liz Cheney    republican      201245
# 1355             59903            Greg Hunter      democrat      201245
# 1356              6918       Richard Brubaker   libertarian      201245
# 1357              6070  Daniel Clyde Cummings  constitution      201245
# 1358               391                    NaN           NaN      201245
#
#       state_fips state_po
# 0              2       AK
# 1              2       AK
# 2              2       AK
# 3              1       AL
# 4              1       AL
# ...          ...      ...
# 1354          56       WY
# 1355          56       WY
# 1356          56       WY
# 1357          56       WY
# 1358          56       WY
#
# [1359 rows x 11 columns]

# %%
df = combined_df[combined_df.candidatevotes_x == combined_df.candidatevotes_y]
df.drop(columns ='candidatevotes_x', inplace = True)
df = df.rename(columns = {"candidatevotes_y": "candidatevotes"})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#df.to_csv('house_2018_win.csv', index = False)

# %% [markdown]
# # 2016

# %%
max_votes_16 = data_2016.groupby('state_district')['candidatevotes'].max()               
max_votes_16 = pd.DataFrame(max_votes_16)

# %%
combined_df_16 = max_votes_16.merge(data_2016[["year","state", "district", "candidatevotes", "state_district", "candidate", "party", "totalvotes", "state_fips", "state_po"]],\
                          on = "state_district",  how = "left")
combined_df_16
# Out:
#      state_district  candidatevotes_x  year    state  district  \
# 0             AK, 0            155088  2016   Alaska         0
# 1             AK, 0            155088  2016   Alaska         0
# 2             AK, 0            155088  2016   Alaska         0
# 3             AK, 0            155088  2016   Alaska         0
# 4             AK, 0            155088  2016   Alaska         0
# ...             ...               ...   ...      ...       ...
# 1435          WY, 0            156176  2016  Wyoming         0
# 1436          WY, 0            156176  2016  Wyoming         0
# 1437          WY, 0            156176  2016  Wyoming         0
# 1438          WY, 0            156176  2016  Wyoming         0
# 1439          WY, 0            156176  2016  Wyoming         0
#
#       candidatevotes_y                 candidate         party  totalvotes  \
# 0                 9093       Bernie Souphanavong          none      308198
# 1               155088                 Don Young    republican      308198
# 2                 1228                       NaN           NaN      308198
# 3               111019            Steve Lindbeck      democrat      308198
# 4                31770          Jim C. McDermott   libertarian      308198
# ...                ...                       ...           ...         ...
# 1435             10362     Daniel Clyde Cummings  constitution      258788
# 1436             75466               Ryan Greene      democrat      258788
# 1437               739                       NaN           NaN      258788
# 1438              9033  Lawrence Gerard Struempf   libertarian      258788
# 1439            156176                Liz Cheney    republican      258788
#
#       state_fips state_po
# 0              2       AK
# 1              2       AK
# 2              2       AK
# 3              2       AK
# 4              2       AK
# ...          ...      ...
# 1435          56       WY
# 1436          56       WY
# 1437          56       WY
# 1438          56       WY
# 1439          56       WY
#
# [1440 rows x 11 columns]

# %%
df_16 = combined_df_16[combined_df_16.candidatevotes_x == combined_df_16.candidatevotes_y]
df_16.drop(columns ='candidatevotes_x', inplace = True)
df_16 = df_16.rename(columns = {"candidatevotes_y": "candidatevotes"})

# %%
df_16
# Out:
#      state_district  year          state  district  candidatevotes  \
# 1             AK, 0  2016         Alaska         0          155088
# 5             AL, 1  2016        Alabama         1          208083
# 9             AL, 2  2016        Alabama         2          134886
# 11            AL, 3  2016        Alabama         3          192164
# 14            AL, 4  2016        Alabama         4          235925
# ...             ...   ...            ...       ...             ...
# 1422          WI, 8  2016      Wisconsin         8          227892
# 1427          WV, 1  2016  West Virginia         1          163469
# 1429          WV, 2  2016  West Virginia         2          140807
# 1431          WV, 3  2016  West Virginia         3          140741
# 1439          WY, 0  2016        Wyoming         0          156176
#
#                 candidate       party  totalvotes  state_fips state_po
# 1               Don Young  republican      308198           2       AK
# 5           Bradley Byrne  republican      215893           1       AL
# 9             Martha Roby  republican      276584           1       AL
# 11            Mike Rogers  republican      287104           1       AL
# 14     Robert B. Aderholt  republican      239444           1       AL
# ...                   ...         ...         ...         ...      ...
# 1422       Mike Gallagher  republican      363780          55       WI
# 1427    David B. McKinley  republican      237003          54       WV
# 1429  Alexander X. Mooney  republican      242014          54       WV
# 1431      Evan H. Jenkins  republican      207332          54       WV
# 1439           Liz Cheney  republican      258788          56       WY
#
# [435 rows x 10 columns]

# %%
#df.to_csv('house_2016_winner.csv', index = False)

# %% [markdown]
# # 2014

# %%
max_votes_14 = data_2014.groupby('state_district')['candidatevotes'].max()               
max_votes_14 = pd.DataFrame(max_votes_14)

# %%
combined_df_14 = max_votes_14.merge(data_2014[["year","state", "district", "candidatevotes", "state_district", "candidate", "party", "totalvotes", "state_fips", "state_po"]],\
                          on = "state_district",  how = "left")
combined_df_14
# Out:
#      state_district  candidatevotes_x  year    state  district  \
# 0             AK, 0            142572  2014   Alaska         0
# 1             AK, 0            142572  2014   Alaska         0
# 2             AK, 0            142572  2014   Alaska         0
# 3             AK, 0            142572  2014   Alaska         0
# 4             AL, 1            103758  2014  Alabama         1
# ...             ...               ...   ...      ...       ...
# 1352          WY, 0            113038  2014  Wyoming         0
# 1353          WY, 0            113038  2014  Wyoming         0
# 1354          WY, 0            113038  2014  Wyoming         0
# 1355          WY, 0            113038  2014  Wyoming         0
# 1356          WY, 0            113038  2014  Wyoming         0
#
#       candidatevotes_y              candidate         party  totalvotes  \
# 0               142572              Don Young    republican      279741
# 1                 1277                    NaN           NaN      279741
# 2               114602         Forrest Dunbar      democrat      279741
# 3                21290       Jim C. McDermott   libertarian      279741
# 4               103758          Bradley Byrne    republican      152234
# ...                ...                    ...           ...         ...
# 1352              5683             Blank Vote           NaN      171153
# 1353            113038      Cynthia M. Lummis    republican      171153
# 1354             37803        Richard Grayson      democrat      171153
# 1355              6749  Daniel Clyde Cummings  constitution      171153
# 1356              7112       Richard Brubaker   libertarian      171153
#
#       state_fips state_po
# 0              2       AK
# 1              2       AK
# 2              2       AK
# 3              2       AK
# 4              1       AL
# ...          ...      ...
# 1352          56       WY
# 1353          56       WY
# 1354          56       WY
# 1355          56       WY
# 1356          56       WY
#
# [1357 rows x 11 columns]

# %%
df_14 = combined_df_14[combined_df_14.candidatevotes_x == combined_df_14.candidatevotes_y]
df_14.drop(columns ='candidatevotes_x', inplace = True)
df_14 = df_14.rename(columns = {"candidatevotes_y": "candidatevotes"})

# %%
df_14
# Out:
#      state_district  year          state  district  candidatevotes  \
# 0             AK, 0  2014         Alaska         0          142572
# 4             AL, 1  2014        Alabama         1          103758
# 7             AL, 2  2014        Alabama         2          113103
# 12            AL, 3  2014        Alabama         3          103558
# 13            AL, 4  2014        Alabama         4          132831
# ...             ...   ...            ...       ...             ...
# 1337          WI, 8  2014      Wisconsin         8          188553
# 1341          WV, 1  2014  West Virginia         1           92491
# 1345          WV, 2  2014  West Virginia         2           72619
# 1349          WV, 3  2014  West Virginia         3           77713
# 1353          WY, 0  2014        Wyoming         0          113038
#
#                candidate       party  totalvotes  state_fips state_po
# 0              Don Young  republican      279741           2       AK
# 4          Bradley Byrne  republican      152234           1       AL
# 7            Martha Roby  republican      167952           1       AL
# 12           Mike Rogers  republican      156620           1       AL
# 13    Robert B. Aderholt  republican      134752           1       AL
# ...                  ...         ...         ...         ...      ...
# 1337      Reid J. Ribble  republican      290048          55       WI
# 1341   David B. McKinley  republican      144737          54       WV
# 1345      Alex X. Mooney  republican      154250          54       WV
# 1349        Evan Jenkins  republican      140401          54       WV
# 1353   Cynthia M. Lummis  republican      171153          56       WY
#
# [435 rows x 10 columns]

# %%
#df_14.to_csv('house_2014_winner.csv', index = False)

# %% [markdown]
# # data all

# %%
combined = df_14.append([df_16, df])

# %%
combined
# Out:
#      state_district  year          state  district  candidatevotes  \
# 0             AK, 0  2014         Alaska         0          142572
# 4             AL, 1  2014        Alabama         1          103758
# 7             AL, 2  2014        Alabama         2          113103
# 12            AL, 3  2014        Alabama         3          103558
# 13            AL, 4  2014        Alabama         4          132831
# ...             ...   ...            ...       ...             ...
# 1344          WI, 8  2018      Wisconsin         8          209410
# 1347          WV, 1  2018  West Virginia         1          127997
# 1349          WV, 2  2018  West Virginia         2          110504
# 1352          WV, 3  2018  West Virginia         3           98645
# 1354          WY, 0  2018        Wyoming         0          127963
#
#                candidate       party  totalvotes  state_fips state_po
# 0              Don Young  republican      279741           2       AK
# 4          Bradley Byrne  republican      152234           1       AL
# 7            Martha Roby  republican      167952           1       AL
# 12           Mike Rogers  republican      156620           1       AL
# 13    Robert B. Aderholt  republican      134752           1       AL
# ...                  ...         ...         ...         ...      ...
# 1344      Mike Gallagher  republican      328774          55       WI
# 1347    David B McKinley  republican      198214          54       WV
# 1349      Alex X. Mooney  republican      204792          54       WV
# 1352        Carol Miller  republican      174985          54       WV
# 1354          Liz Cheney  republican      201245          56       WY
#
# [1305 rows x 10 columns]

# %%
combined.loc[combined['party'] == 'democratic-farmer-labor']
# Out:
#     state_district  year      state  district  candidatevotes  \
# 593          MN, 1  2014  Minnesota         1          122851
# 604          MN, 4  2014  Minnesota         4          147857
# 616          MN, 7  2014  Minnesota         7          130546
# 581          MN, 2  2018  Minnesota         2          177958
# 584          MN, 3  2018  Minnesota         3          202404
# 587          MN, 4  2018  Minnesota         4          216865
# 591          MN, 5  2018  Minnesota         5          267703
# 597          MN, 7  2018  Minnesota         7          146672
#
#               candidate                    party  totalvotes  state_fips  \
# 593     Timothy J. Walz  democratic-farmer-labor      226695          27
# 604      Betty McCollum  democratic-farmer-labor      241637          27
# 616  Collin C. Peterson  democratic-farmer-labor      240835          27
# 581         Angie Craig  democratic-farmer-labor      337968          27
# 584       Dean Phillips  democratic-farmer-labor      363949          27
# 587      Betty McCollum  democratic-farmer-labor      328614          27
# 591          Ilhan Omar  democratic-farmer-labor      343358          27
# 597  Collin C. Peterson  democratic-farmer-labor      281509          27
#
#     state_po
# 593       MN
# 604       MN
# 616       MN
# 581       MN
# 584       MN
# 587       MN
# 591       MN
# 597       MN

# %%
combined
# Out:
#      state_district  year          state  district  candidatevotes  \
# 0             AK, 0  2014         Alaska         0          142572
# 4             AL, 1  2014        Alabama         1          103758
# 7             AL, 2  2014        Alabama         2          113103
# 12            AL, 3  2014        Alabama         3          103558
# 13            AL, 4  2014        Alabama         4          132831
# ...             ...   ...            ...       ...             ...
# 1344          WI, 8  2018      Wisconsin         8          209410
# 1347          WV, 1  2018  West Virginia         1          127997
# 1349          WV, 2  2018  West Virginia         2          110504
# 1352          WV, 3  2018  West Virginia         3           98645
# 1354          WY, 0  2018        Wyoming         0          127963
#
#                candidate       party  totalvotes  state_fips state_po
# 0              Don Young  republican      279741           2       AK
# 4          Bradley Byrne  republican      152234           1       AL
# 7            Martha Roby  republican      167952           1       AL
# 12           Mike Rogers  republican      156620           1       AL
# 13    Robert B. Aderholt  republican      134752           1       AL
# ...                  ...         ...         ...         ...      ...
# 1344      Mike Gallagher  republican      328774          55       WI
# 1347    David B McKinley  republican      198214          54       WV
# 1349      Alex X. Mooney  republican      204792          54       WV
# 1352        Carol Miller  republican      174985          54       WV
# 1354          Liz Cheney  republican      201245          56       WY
#
# [1305 rows x 10 columns]

# %%
combined = combined.replace('democratic-farmer-labor', 'democrat')

# %%
combined.loc[combined['party'] == 'democratic']
# Out:
# Empty DataFrame
# Columns: [state_district, year, state, district, candidatevotes, candidate, party, totalvotes, state_fips, state_po]
# Index: []

# %%
combined['party'].unique()
# Out:
# array(['republican', 'democrat'], dtype=object)

# %%
#combined.to_csv("house_data_14_16_18_final.csv")

# %% [markdown]
# # State / Party df

# %%
combined_fips = combined_df_16[['state_fips','state']]

# %%
combined_fips = combined_fips.drop_duplicates(subset = 'state')
combined_fips
# Out:
#       state_fips           state
# 0              2          Alaska
# 5              1         Alabama
# 23             5        Arkansas
# 33             4         Arizona
# 59             6      California
# 165            8        Colorado
# 187            9     Connecticut
# 213           10        Delaware
# 217           12         Florida
# 287           13         Georgia
# 313           15          Hawaii
# 323           19            Iowa
# 338           16           Idaho
# 344           17        Illinois
# 386           18         Indiana
# 413           20          Kansas
# 427           21        Kentucky
# 438           22       Louisiana
# 476           25   Massachusetts
# 512           24        Maryland
# 553           23           Maine
# 561           26        Michigan
# 623           27       Minnesota
# 650           29        Missouri
# 679           28     Mississippi
# 695           30         Montana
# 698           37  North Carolina
# 725           38    North Dakota
# 729           31        Nebraska
# 735           33   New Hampshire
# 747           34      New Jersey
# 800           35      New Mexico
# 807           32          Nevada
# 823           36        New York
# 1034          39            Ohio
# 1078          40        Oklahoma
# 1090          41          Oregon
# 1110          42    Pennsylvania
# 1145          44    Rhode Island
# 1153          45  South Carolina
# 1186          46    South Dakota
# 1188          47       Tennessee
# 1219          48           Texas
# 1323          49            Utah
# 1335          51        Virginia
# 1370          50         Vermont
# 1375          53      Washington
# 1395          55       Wisconsin
# 1426          54   West Virginia
# 1433          56         Wyoming

# %%
df_16  =df_16.replace('democratic-farmer-labor', 'democrat')

# %%
state_party_16 = pd.DataFrame(df_16.groupby("state")['party'].describe())
state_party_16['year'] = 2016
state_party_14 = pd.DataFrame(df_14.groupby("state")['party'].describe())
state_party_14['year'] = 2014
state_party_18 = pd.DataFrame(df.groupby("state")['party'].describe())
state_party_18 = state_party_18.replace('democratic-farmer-labor', 'democrat')
state_party_18['year'] = 2018

state_party_all = state_party_14.append([state_party_16, state_party_18])

# %%
result = pd.merge(state_party_all, combined_fips, on = 'state')
#result.drop(columns = ['state_fips_x', 'state_fips_y'])
result = result.drop_duplicates(subset = ['state', 'year'])
result
# Out:
#          state count unique         top freq  year  state_fips
# 0      Alabama     7      2  republican    6  2014           1
# 1      Alabama     7      2  republican    6  2016           1
# 2      Alabama     7      2  republican    6  2018           1
# 3       Alaska     1      1  republican    1  2014           2
# 4       Alaska     1      1  republican    1  2016           2
# ..         ...   ...    ...         ...  ...   ...         ...
# 145  Wisconsin     8      2  republican    5  2016          55
# 146  Wisconsin     8      2  republican    5  2018          55
# 147    Wyoming     1      1  republican    1  2014          56
# 148    Wyoming     1      1  republican    1  2016          56
# 149    Wyoming     1      1  republican    1  2018          56
#
# [150 rows x 7 columns]

# %%
# AWS Connection
from sqlalchemy import create_engine
rds_connection_string = "postgres:postgres@electionanalysis.c2buyytj82fm.us-west-1.rds.amazonaws.com:5432/Election_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['combined_presidential_table',
#  'house_elections_table',
#  'senate_elections_table']

# %%
# # Import House Election Table 
import pandas as pd
pd.read_sql_query('select * from house_elections_table', con=engine).head()
# Out:
#   state_district  year    state  district  candidate_votes  \
# 0         AK - 0  2014   Alaska         0           142572
# 1         AL - 1  2014  Alabama         1           103758
# 2         AL - 2  2014  Alabama         2           113103
# 3         AL - 3  2014  Alabama         3           103558
# 4         AL - 4  2014  Alabama         4           132831
#
#             candidate       party  total_votes state_po
# 0           Don Young  republican       279741       AK
# 1       Bradley Byrne  republican       152234       AL
# 2         Martha Roby  republican       167952       AL
# 3         Mike Rogers  republican       156620       AL
# 4  Robert B. Aderholt  republican       134752       AL

# %%
# Import Presidential Election Table 
pd.read_sql_query('select* from combined_presidential_table', con=engine).head()
# Out:
#         State  count  unique         top  frequency  year
# 0     Alabama     67       2  republican         52  2012
# 1      Alaska     40       2  republican         27  2012
# 2     Arizona     15       2  republican         11  2012
# 3    Arkansas     75       2  republican         66  2012
# 4  California     58       2    democrat         31  2012

# %%
#Import Senate Election Table 
pd.read_sql_query('select* from senate_elections_table', con=engine).head()
# Out:
#    year     state  state_fips stage special             candidate     party  \
# 0  2014    Alaska           2   gen   FALSE           Mark Begich  democrat
# 1  2014  Arkansas           5   gen   FALSE         Mark L. Pryor  democrat
# 2  2014  Colorado           8   gen   FALSE            Mark Udall  democrat
# 3  2014  Delaware          10   gen   FALSE  Christopher A. Coons  democrat
# 4  2014   Georgia          13   gen   FALSE      M. Michelle Nunn  democrat
#
#    candidatevotes  totalvotes
# 0          129431      282400
# 1          334174      847505
# 2          944203     2041058
# 3          130655      234038
# 4         1160811     2567805

# %%
#state_party_all.to_csv("state_party_all.csv")

# %% [markdown]
# # Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
election = result
X = election[['top', 'year']]
y = election["state_fips"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (150, 2) (150, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
data = X.copy()
data_binary_encoded = pd.get_dummies(data, columns=["top"])
data_binary_encoded.head()
# Out:
#    year  top_democrat  top_republican
# 0  2014             0               1
# 1  2016             0               1
# 2  2018             0               1
# 3  2014             0               1
# 4  2016             0               1

# %%
X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#      year  top_democrat  top_republican
# 4    2016             0               1
# 32   2018             1               0
# 142  2016             0               1
# 85   2016             1               0
# 86   2018             1               0

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["year"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["year"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 1.1754660807248951, R2: -0.10066393340789737

# %% [markdown]
# # Exporting to csv

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
X_train = model.predict(X_train_scaled)
y_train =  (model.predict(X_train_scaled) - y_train_scaled)
X_test = model.predict(X_test_scaled)
y_test = (model.predict(X_test_scaled) - y_test_scaled)

# %%
X_train = pd.DataFrame(np.array(X_train), columns = ['X_train'])
y_train = pd.DataFrame(np.array(y_train), columns = ['y_train'])
X_test = pd.DataFrame(np.array(X_test), columns = ['X_test'])
y_test = pd.DataFrame(np.array(y_test), columns = ['y_test'])

# %%
trained_df = pd.concat([X_train,y_train], axis = 1)

# %%
trained_df.to_csv('House_trained.csv')

# %% [markdown]
# # Testing Deep Learning Model

# %%
voice = result

X = election[['top', 'year']]
y = election["state_fips"]
print(X.shape, y.shape)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

data = X.copy()
data_binary_encoded = pd.get_dummies(data, columns=["top"])
data_binary_encoded.head()

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# (150, 2) (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %%
# Transform the training and testing data using the X_scaler

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

# %%
# One-hot encoding
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=54, activation='relu', input_dim=3))
model.add(Dense(units=54, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 54)                216
# _________________________________________________________________
# dense_35 (Dense)             (None, 54)                2970
# =================================================================
# Total params: 3,186
# Trainable params: 3,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 112 samples
# Epoch 1/100
# 112/112 - 1s - loss: 4.0480 - accuracy: 0.0179
# Epoch 2/100
# 112/112 - 0s - loss: 4.0210 - accuracy: 0.0179
# Epoch 3/100
# 112/112 - 0s - loss: 3.9996 - accuracy: 0.0179
# Epoch 4/100
# 112/112 - 0s - loss: 3.9779 - accuracy: 0.0179
# Epoch 5/100
# 112/112 - 0s - loss: 3.9578 - accuracy: 0.0179
# Epoch 6/100
# 112/112 - 0s - loss: 3.9371 - accuracy: 0.0268
# Epoch 7/100
# 112/112 - 0s - loss: 3.9162 - accuracy: 0.0357
# Epoch 8/100
# 112/112 - 0s - loss: 3.8969 - accuracy: 0.0357
# Epoch 9/100
# 112/112 - 0s - loss: 3.8768 - accuracy: 0.0357
# Epoch 10/100
# 112/112 - 0s - loss: 3.8575 - accuracy: 0.0446
# Epoch 11/100
# 112/112 - 0s - loss: 3.8366 - accuracy: 0.0446
# Epoch 12/100
# 112/112 - 0s - loss: 3.8175 - accuracy: 0.0446
# Epoch 13/100
# 112/112 - 0s - loss: 3.7977 - accuracy: 0.0446
# Epoch 14/100
# 112/112 - 0s - loss: 3.7780 - accuracy: 0.0446
# Epoch 15/100
# 112/112 - 0s - loss: 3.7581 - accuracy: 0.0446
# Epoch 16/100
# 112/112 - 0s - loss: 3.7383 - accuracy: 0.0536
# Epoch 17/100
# 112/112 - 0s - loss: 3.7191 - accuracy: 0.0536
# Epoch 18/100
# 112/112 - 0s - loss: 3.6985 - accuracy: 0.0536
# Epoch 19/100
# 112/112 - 0s - loss: 3.6796 - accuracy: 0.0536
# Epoch 20/100
# 112/112 - 0s - loss: 3.6599 - accuracy: 0.0536
# Epoch 21/100
# 112/112 - 0s - loss: 3.6411 - accuracy: 0.0536
# Epoch 22/100
# 112/112 - 0s - loss: 3.6222 - accuracy: 0.0446
# Epoch 23/100
# 112/112 - 0s - loss: 3.6041 - accuracy: 0.0536
# Epoch 24/100
# 112/112 - 0s - loss: 3.5858 - accuracy: 0.0536
# Epoch 25/100
# 112/112 - 0s - loss: 3.5687 - accuracy: 0.0536
# Epoch 26/100
# 112/112 - 0s - loss: 3.5513 - accuracy: 0.0536
# Epoch 27/100
# 112/112 - 0s - loss: 3.5349 - accuracy: 0.0536
# Epoch 28/100
# 112/112 - 0s - loss: 3.5184 - accuracy: 0.0536
# Epoch 29/100
# 112/112 - 0s - loss: 3.5026 - accuracy: 0.0536
# Epoch 30/100
# 112/112 - 0s - loss: 3.4880 - accuracy: 0.0536
# Epoch 31/100
# 112/112 - 0s - loss: 3.4731 - accuracy: 0.0536
# Epoch 32/100
# 112/112 - 0s - loss: 3.4593 - accuracy: 0.0536
# Epoch 33/100
# 112/112 - 0s - loss: 3.4460 - accuracy: 0.0536
# Epoch 34/100
# 112/112 - 0s - loss: 3.4331 - accuracy: 0.0536
# Epoch 35/100
# 112/112 - 0s - loss: 3.4213 - accuracy: 0.0536
# Epoch 36/100
# 112/112 - 0s - loss: 3.4095 - accuracy: 0.0536
# Epoch 37/100
# 112/112 - 0s - loss: 3.3985 - accuracy: 0.0536
# Epoch 38/100
# 112/112 - 0s - loss: 3.3878 - accuracy: 0.0536
# Epoch 39/100
# 112/112 - 0s - loss: 3.3772 - accuracy: 0.0446
# Epoch 40/100
# 112/112 - 0s - loss: 3.3683 - accuracy: 0.0357
# Epoch 41/100
# 112/112 - 0s - loss: 3.3591 - accuracy: 0.0536
# Epoch 42/100
# 112/112 - 0s - loss: 3.3503 - accuracy: 0.0446
# Epoch 43/100
# 112/112 - 0s - loss: 3.3421 - accuracy: 0.0536
# Epoch 44/100
# 112/112 - 0s - loss: 3.3345 - accuracy: 0.0536
# Epoch 45/100
# 112/112 - 0s - loss: 3.3268 - accuracy: 0.0536
# Epoch 46/100
# 112/112 - 0s - loss: 3.3198 - accuracy: 0.0446
# Epoch 47/100
# 112/112 - 0s - loss: 3.3128 - accuracy: 0.0536
# Epoch 48/100
# 112/112 - 0s - loss: 3.3066 - accuracy: 0.0536
# Epoch 49/100
# 112/112 - 0s - loss: 3.3001 - accuracy: 0.0536
# Epoch 50/100
# 112/112 - 0s - loss: 3.2947 - accuracy: 0.0446
# Epoch 51/100
# 112/112 - 0s - loss: 3.2886 - accuracy: 0.0536
# Epoch 52/100
# 112/112 - 0s - loss: 3.2835 - accuracy: 0.0536
# Epoch 53/100
# 112/112 - 0s - loss: 3.2779 - accuracy: 0.0536
# Epoch 54/100
# 112/112 - 0s - loss: 3.2731 - accuracy: 0.0536
# Epoch 55/100
# 112/112 - 0s - loss: 3.2688 - accuracy: 0.0536
# Epoch 56/100
# 112/112 - 0s - loss: 3.2637 - accuracy: 0.0536
# Epoch 57/100
# 112/112 - 0s - loss: 3.2596 - accuracy: 0.0536
# Epoch 58/100
# 112/112 - 0s - loss: 3.2555 - accuracy: 0.0536
# Epoch 59/100
# 112/112 - 0s - loss: 3.2514 - accuracy: 0.0536
# Epoch 60/100
# 112/112 - 0s - loss: 3.2475 - accuracy: 0.0536
# Epoch 61/100
# 112/112 - 0s - loss: 3.2438 - accuracy: 0.0446
# Epoch 62/100
# 112/112 - 0s - loss: 3.2398 - accuracy: 0.0536
# Epoch 63/100
# 112/112 - 0s - loss: 3.2363 - accuracy: 0.0536
# Epoch 64/100
# 112/112 - 0s - loss: 3.2326 - accuracy: 0.0446
# Epoch 65/100
# 112/112 - 0s - loss: 3.2295 - accuracy: 0.0536
# Epoch 66/100
# 112/112 - 0s - loss: 3.2263 - accuracy: 0.0536
# Epoch 67/100
# 112/112 - 0s - loss: 3.2233 - accuracy: 0.0446
# Epoch 68/100
# 112/112 - 0s - loss: 3.2204 - accuracy: 0.0446
# Epoch 69/100
# 112/112 - 0s - loss: 3.2170 - accuracy: 0.0536
# Epoch 70/100
# 112/112 - 0s - loss: 3.2143 - accuracy: 0.0536
# Epoch 71/100
# 112/112 - 0s - loss: 3.2120 - accuracy: 0.0536
# Epoch 72/100
# 112/112 - 0s - loss: 3.2092 - accuracy: 0.0536
# Epoch 73/100
# 112/112 - 0s - loss: 3.2063 - accuracy: 0.0536
# Epoch 74/100
# 112/112 - 0s - loss: 3.2035 - accuracy: 0.0536
# Epoch 75/100
# 112/112 - 0s - loss: 3.2018 - accuracy: 0.0536
# Epoch 76/100
# 112/112 - 0s - loss: 3.1990 - accuracy: 0.0536
# Epoch 77/100
# 112/112 - 0s - loss: 3.1967 - accuracy: 0.0536
# Epoch 78/100
# 112/112 - 0s - loss: 3.1943 - accuracy: 0.0536
# Epoch 79/100
# 112/112 - 0s - loss: 3.1919 - accuracy: 0.0536
# Epoch 80/100
# 112/112 - 0s - loss: 3.1899 - accuracy: 0.0536
# Epoch 81/100
# 112/112 - 0s - loss: 3.1879 - accuracy: 0.0536
# Epoch 82/100
# 112/112 - 0s - loss: 3.1855 - accuracy: 0.0536
# Epoch 83/100
# 112/112 - 0s - loss: 3.1837 - accuracy: 0.0536
# Epoch 84/100
# 112/112 - 0s - loss: 3.1813 - accuracy: 0.0536
# Epoch 85/100
# 112/112 - 0s - loss: 3.1793 - accuracy: 0.0446
# Epoch 86/100
# 112/112 - 0s - loss: 3.1771 - accuracy: 0.0536
# Epoch 87/100
# 112/112 - 0s - loss: 3.1755 - accuracy: 0.0536
# Epoch 88/100
# 112/112 - 0s - loss: 3.1739 - accuracy: 0.0536
# Epoch 89/100
# 112/112 - 0s - loss: 3.1722 - accuracy: 0.0536
# Epoch 90/100
# 112/112 - 0s - loss: 3.1704 - accuracy: 0.0446
# Epoch 91/100
# 112/112 - 0s - loss: 3.1682 - accuracy: 0.0536
# Epoch 92/100
# 112/112 - 0s - loss: 3.1667 - accuracy: 0.0536
# Epoch 93/100
# 112/112 - 0s - loss: 3.1650 - accuracy: 0.0536
# Epoch 94/100
# 112/112 - 0s - loss: 3.1631 - accuracy: 0.0536
# Epoch 95/100
# 112/112 - 0s - loss: 3.1624 - accuracy: 0.0446
# Epoch 96/100
# 112/112 - 0s - loss: 3.1601 - accuracy: 0.0536
# Epoch 97/100
# 112/112 - 0s - loss: 3.1592 - accuracy: 0.0536
# Epoch 98/100
# 112/112 - 0s - loss: 3.1572 - accuracy: 0.0536
# Epoch 99/100
# 112/112 - 0s - loss: 3.1560 - accuracy: 0.0536
# Epoch 100/100
# 112/112 - 0s - loss: 3.1541 - accuracy: 0.0536

# %%
deep_model = Sequential()
deep_model.add(Dense(units=54, activation='relu', input_dim=3))
deep_model.add(Dense(units=54, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 54)                216
# _________________________________________________________________
# dense_43 (Dense)             (None, 54)                2970
# =================================================================
# Total params: 3,186
# Trainable params: 3,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# %%
deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 112 samples
# Epoch 1/100
# 112/112 - 0s - loss: 4.0863 - accuracy: 0.0357
# Epoch 2/100
# 112/112 - 0s - loss: 4.0594 - accuracy: 0.0357
# Epoch 3/100
# 112/112 - 0s - loss: 4.0366 - accuracy: 0.0446
# Epoch 4/100
# 112/112 - 0s - loss: 4.0149 - accuracy: 0.0446
# Epoch 5/100
# 112/112 - 0s - loss: 3.9933 - accuracy: 0.0446
# Epoch 6/100
# 112/112 - 0s - loss: 3.9732 - accuracy: 0.0446
# Epoch 7/100
# 112/112 - 0s - loss: 3.9518 - accuracy: 0.0446
# Epoch 8/100
# 112/112 - 0s - loss: 3.9316 - accuracy: 0.0446
# Epoch 9/100
# 112/112 - 0s - loss: 3.9108 - accuracy: 0.0446
# Epoch 10/100
# 112/112 - 0s - loss: 3.8908 - accuracy: 0.0446
# Epoch 11/100
# 112/112 - 0s - loss: 3.8696 - accuracy: 0.0446
# Epoch 12/100
# 112/112 - 0s - loss: 3.8495 - accuracy: 0.0446
# Epoch 13/100
# 112/112 - 0s - loss: 3.8284 - accuracy: 0.0446
# Epoch 14/100
# 112/112 - 0s - loss: 3.8076 - accuracy: 0.0446
# Epoch 15/100
# 112/112 - 0s - loss: 3.7859 - accuracy: 0.0446
# Epoch 16/100
# 112/112 - 0s - loss: 3.7647 - accuracy: 0.0446
# Epoch 17/100
# 112/112 - 0s - loss: 3.7435 - accuracy: 0.0446
# Epoch 18/100
# 112/112 - 0s - loss: 3.7219 - accuracy: 0.0446
# Epoch 19/100
# 112/112 - 0s - loss: 3.7004 - accuracy: 0.0536
# Epoch 20/100
# 112/112 - 0s - loss: 3.6790 - accuracy: 0.0536
# Epoch 21/100
# 112/112 - 0s - loss: 3.6580 - accuracy: 0.0536
# Epoch 22/100
# 112/112 - 0s - loss: 3.6370 - accuracy: 0.0536
# Epoch 23/100
# 112/112 - 0s - loss: 3.6162 - accuracy: 0.0536
# Epoch 24/100
# 112/112 - 0s - loss: 3.5970 - accuracy: 0.0536
# Epoch 25/100
# 112/112 - 0s - loss: 3.5766 - accuracy: 0.0536
# Epoch 26/100
# 112/112 - 0s - loss: 3.5579 - accuracy: 0.0536
# Epoch 27/100
# 112/112 - 0s - loss: 3.5389 - accuracy: 0.0536
# Epoch 28/100
# 112/112 - 0s - loss: 3.5215 - accuracy: 0.0536
# Epoch 29/100
# 112/112 - 0s - loss: 3.5049 - accuracy: 0.0536
# Epoch 30/100
# 112/112 - 0s - loss: 3.4880 - accuracy: 0.0536
# Epoch 31/100
# 112/112 - 0s - loss: 3.4718 - accuracy: 0.0536
# Epoch 32/100
# 112/112 - 0s - loss: 3.4570 - accuracy: 0.0536
# Epoch 33/100
# 112/112 - 0s - loss: 3.4424 - accuracy: 0.0536
# Epoch 34/100
# 112/112 - 0s - loss: 3.4294 - accuracy: 0.0536
# Epoch 35/100
# 112/112 - 0s - loss: 3.4164 - accuracy: 0.0536
# Epoch 36/100
# 112/112 - 0s - loss: 3.4042 - accuracy: 0.0536
# Epoch 37/100
# 112/112 - 0s - loss: 3.3926 - accuracy: 0.0536
# Epoch 38/100
# 112/112 - 0s - loss: 3.3821 - accuracy: 0.0536
# Epoch 39/100
# 112/112 - 0s - loss: 3.3719 - accuracy: 0.0536
# Epoch 40/100
# 112/112 - 0s - loss: 3.3625 - accuracy: 0.0536
# Epoch 41/100
# 112/112 - 0s - loss: 3.3532 - accuracy: 0.0536
# Epoch 42/100
# 112/112 - 0s - loss: 3.3448 - accuracy: 0.0536
# Epoch 43/100
# 112/112 - 0s - loss: 3.3371 - accuracy: 0.0536
# Epoch 44/100
# 112/112 - 0s - loss: 3.3289 - accuracy: 0.0536
# Epoch 45/100
# 112/112 - 0s - loss: 3.3222 - accuracy: 0.0446
# Epoch 46/100
# 112/112 - 0s - loss: 3.3154 - accuracy: 0.0536
# Epoch 47/100
# 112/112 - 0s - loss: 3.3091 - accuracy: 0.0536
# Epoch 48/100
# 112/112 - 0s - loss: 3.3035 - accuracy: 0.0536
# Epoch 49/100
# 112/112 - 0s - loss: 3.2973 - accuracy: 0.0536
# Epoch 50/100
# 112/112 - 0s - loss: 3.2923 - accuracy: 0.0536
# Epoch 51/100
# 112/112 - 0s - loss: 3.2869 - accuracy: 0.0536
# Epoch 52/100
# 112/112 - 0s - loss: 3.2814 - accuracy: 0.0536
# Epoch 53/100
# 112/112 - 0s - loss: 3.2770 - accuracy: 0.0536
# Epoch 54/100
# 112/112 - 0s - loss: 3.2727 - accuracy: 0.0536
# Epoch 55/100
# 112/112 - 0s - loss: 3.2685 - accuracy: 0.0446
# Epoch 56/100
# 112/112 - 0s - loss: 3.2646 - accuracy: 0.0536
# Epoch 57/100
# 112/112 - 0s - loss: 3.2608 - accuracy: 0.0536
# Epoch 58/100
# 112/112 - 0s - loss: 3.2572 - accuracy: 0.0536
# Epoch 59/100
# 112/112 - 0s - loss: 3.2536 - accuracy: 0.0536
# Epoch 60/100
# 112/112 - 0s - loss: 3.2503 - accuracy: 0.0446
# Epoch 61/100
# 112/112 - 0s - loss: 3.2467 - accuracy: 0.0536
# Epoch 62/100
# 112/112 - 0s - loss: 3.2436 - accuracy: 0.0536
# Epoch 63/100
# 112/112 - 0s - loss: 3.2408 - accuracy: 0.0536
# Epoch 64/100
# 112/112 - 0s - loss: 3.2379 - accuracy: 0.0446
# Epoch 65/100
# 112/112 - 0s - loss: 3.2349 - accuracy: 0.0536
# Epoch 66/100
# 112/112 - 0s - loss: 3.2323 - accuracy: 0.0536
# Epoch 67/100
# 112/112 - 0s - loss: 3.2295 - accuracy: 0.0536
# Epoch 68/100
# 112/112 - 0s - loss: 3.2265 - accuracy: 0.0536
# Epoch 69/100
# 112/112 - 0s - loss: 3.2243 - accuracy: 0.0536
# Epoch 70/100
# 112/112 - 0s - loss: 3.2213 - accuracy: 0.0536
# Epoch 71/100
# 112/112 - 0s - loss: 3.2189 - accuracy: 0.0536
# Epoch 72/100
# 112/112 - 0s - loss: 3.2168 - accuracy: 0.0536
# Epoch 73/100
# 112/112 - 0s - loss: 3.2142 - accuracy: 0.0536
# Epoch 74/100
# 112/112 - 0s - loss: 3.2117 - accuracy: 0.0536
# Epoch 75/100
# 112/112 - 0s - loss: 3.2100 - accuracy: 0.0536
# Epoch 76/100
# 112/112 - 0s - loss: 3.2078 - accuracy: 0.0446
# Epoch 77/100
# 112/112 - 0s - loss: 3.2059 - accuracy: 0.0536
# Epoch 78/100
# 112/112 - 0s - loss: 3.2035 - accuracy: 0.0446
# Epoch 79/100
# 112/112 - 0s - loss: 3.2016 - accuracy: 0.0536
# Epoch 80/100
# 112/112 - 0s - loss: 3.1992 - accuracy: 0.0446
# Epoch 81/100
# 112/112 - 0s - loss: 3.1975 - accuracy: 0.0536
# Epoch 82/100
# 112/112 - 0s - loss: 3.1954 - accuracy: 0.0536
# Epoch 83/100
# 112/112 - 0s - loss: 3.1933 - accuracy: 0.0536
# Epoch 84/100
# 112/112 - 0s - loss: 3.1914 - accuracy: 0.0536
# Epoch 85/100
# 112/112 - 0s - loss: 3.1896 - accuracy: 0.0625
# Epoch 86/100
# 112/112 - 0s - loss: 3.1881 - accuracy: 0.0536
# Epoch 87/100
# 112/112 - 0s - loss: 3.1858 - accuracy: 0.0446
# Epoch 88/100
# 112/112 - 0s - loss: 3.1846 - accuracy: 0.0536
# Epoch 89/100
# 112/112 - 0s - loss: 3.1829 - accuracy: 0.0536
# Epoch 90/100
# 112/112 - 0s - loss: 3.1810 - accuracy: 0.0357
# Epoch 91/100
# 112/112 - 0s - loss: 3.1798 - accuracy: 0.0536
# Epoch 92/100
# 112/112 - 0s - loss: 3.1781 - accuracy: 0.0536
# Epoch 93/100
# 112/112 - 0s - loss: 3.1772 - accuracy: 0.0536
# Epoch 94/100
# 112/112 - 0s - loss: 3.1755 - accuracy: 0.0536
# Epoch 95/100
# 112/112 - 0s - loss: 3.1738 - accuracy: 0.0536
# Epoch 96/100
# 112/112 - 0s - loss: 3.1721 - accuracy: 0.0536
# Epoch 97/100
# 112/112 - 0s - loss: 3.1709 - accuracy: 0.0536
# Epoch 98/100
# 112/112 - 0s - loss: 3.1696 - accuracy: 0.0536
# Epoch 99/100
# 112/112 - 0s - loss: 3.1682 - accuracy: 0.0446
# Epoch 100/100
# 112/112 - 0s - loss: 3.1668 - accuracy: 0.0536

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 38/1 - 0s - loss: 4.1045 - accuracy: 0.0000e+00
# Normal Neural Network - Loss: 4.073468735343532, Accuracy: 0.0

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 38/1 - 0s - loss: 3.9095 - accuracy: 0.0263
# Deep Neural Network - Loss: 3.986650253597059, Accuracy: 0.02631578966975212
