# %%
import pandas as pd

# %%
pd.read_csv("Resources/presidential_ev_probabilities_2020.csv")
# Out:
#      cycle     branch       model  modeldate candidate_inc candidate_chal  \
# 0     2020  President  polls-plus  8/17/2020         Trump          Biden
# 1     2020  President  polls-plus  8/17/2020         Trump          Biden
# 2     2020  President  polls-plus  8/17/2020         Trump          Biden
# 3     2020  President  polls-plus  8/17/2020         Trump          Biden
# 4     2020  President  polls-plus  8/17/2020         Trump          Biden
# ..     ...        ...         ...        ...           ...            ...
# 534   2020  President  polls-plus  8/17/2020         Trump          Biden
# 535   2020  President  polls-plus  8/17/2020         Trump          Biden
# 536   2020  President  polls-plus  8/17/2020         Trump          Biden
# 537   2020  President  polls-plus  8/17/2020         Trump          Biden
# 538   2020  President  polls-plus  8/17/2020         Trump          Biden
#
#      candidate_3rd  evprob_inc  evprob_chal  evprob_3rd  total_ev  \
# ...
